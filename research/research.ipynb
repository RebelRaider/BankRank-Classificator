# %%
import pandas as pd
csv = pd.read_csv('../output/features_with_category.csv')

# %%
csv.dropna()
# Out:
#                                                pr_txt  \
# 4   Кредитный рейтинг  ООО «Электрощит-Стройсистем...
# 11  Кредитный рейтинг  АО «Коммерческая недвижимос...
# 12  Кредитный рейтинг  Yandex N.V.  (далее — Yande...
# 37  «Эксперт РА» подтвердил кредитный рейтинг АО «...
# 47  Кредитный рейтинг  АО «Зарубежнефть»  (далее —...
# 48  Подтверждение кредитного рейтинга  ПАО «Распад...
# 63  Кредитный рейтинг  Акционерного общества «Объе...
# 66  Собственная кредитоспособность  ПАО «НК «Росне...
# 73  Кредитный рейтинг  ООО «Левел Груп» (далее — К...
# 74  Подтверждение кредитного рейтинга  EVRAZ plc  ...
# 77  16 января 2023 г. Ведущий рейтинговый аналитик...
#
#                                            clean_text   count  \
# 4   кредитный рейтинг ооо электрощит-стройсистема ...   920.0
# 11  кредитный рейтинг ао коммерческий недвижимость...   913.0
# 12  кредитный рейтинг yandex n.v. далее yandex n.v...   998.0
# 37  эксперт ра подтвердить кредитный рейтинг ао за...  1237.0
# ...
