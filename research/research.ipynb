# %%
также напиши backend/config.py и добавь туда корректно и качественно все конфигурации (важные параметры обучения, пути к файлам к примеру dataset у нас resources/dataset/train.csv, модели в resources/models)
исследование данных запиши в backend/research.py.

# %%
import pandas as pd
csv = pd.read_csv('../resources/dataset/train.csv')

# %%
csv
# Out:
#         Id                                             pr_txt Категория  \
# 0        1  Повышение кредитного рейтинга  Акционерного об...         A
# 1        2  «Эксперт РА» подтвердил кредитный рейтинг комп...        BB
# 2        3  НКР повысило кредитный рейтинг ООО "ОТЭКО-Порт...         A
# 3        4  «Эксперт РА» присвоил кредитный рейтинг ПАО «Ф...       AAA
# 4        5  29 марта 2023 г. Ведущий рейтинговый аналитик ...       BBB
# ...    ...                                                ...       ...
# 1195  1207  «Эксперт РА» подтвердил рейтинг компании «Татн...       AAA
# 1196  1208  «Эксперт РА» понизил рейтинг компании «Инвестг...        BB
# 1197  1209  АКРА подтвердило ПАО «КАМАЗ» кредитный рейтинг...         A
# 1198  1210  АКРА подтвердило кредитный рейтинг ФГУП «Почта...       AAA
# 1199  1211  «Эксперт РА» подтвердил рейтинг компании «СИБИ...        BB
#
#      Уровень рейтинга
# 0                   A
# 1                  BB
# 2                   A
# ...
